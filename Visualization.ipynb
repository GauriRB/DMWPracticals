# %%
pip install seaborn
# Out:
# ...
#      ------------------------------------ 293.3/293.3 kB 647.7 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as snb

# %%
d=pd.read_csv('IRIS.csv')

# %%
d
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
d.shape
# Out:
# (150, 5)

# %%
d.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
d.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# # Histogram

# %%
d.hist()
# Out:
# array([[<AxesSubplot: title={'center': 'sepal_length'}>,
#         <AxesSubplot: title={'center': 'sepal_width'}>],
#        [<AxesSubplot: title={'center': 'petal_length'}>,
#         <AxesSubplot: title={'center': 'petal_width'}>]], dtype=object)

# %% [markdown]
# # Countplot

# %%
snb.countplot(data=d,x='petal_length')
# Out:
# <AxesSubplot: xlabel='petal_length', ylabel='count'>

# %%
snb.countplot(data=d,x='petal_length', hue='sepal_length')
# Out:
# <AxesSubplot: xlabel='petal_length', ylabel='count'>

# %%
snb.countplot(data=d,x='species')
plt.title("countplot for species")
# Out:
# Text(0.5, 1.0, 'countplot for species')

# %% [markdown]
# # Piechart

# %%
labels=['setosa','versicolor species','virginica']
sizes=[50,50,50]

# %%
plt.pie(sizes,labels=labels,explode=(0.1,0.1,0.1))
# Out:
# ([<matplotlib.patches.Wedge at 0x18a5dada7a0>,
# ...
#  [Text(0.5999999675667398, 1.0392305032666773, 'setosa'),
#   Text(-1.199999999999995, -1.1235210826980003e-07, 'versicolor species'),
#   Text(0.6000001621662929, -1.0392303909145566, 'virginica')])

# %%
a=np.array(d['petal_length'])
plt.pie(a)
# Out:
# ([<matplotlib.patches.Wedge at 0x18a5db2d240>,
# ...
#  [Text(1.0999665292027312, 0.008581062503984837, ''),
#   Text(1.099698775045848, 0.025741098707345537, ''),
#   Text(1.0991870630368616, 0.04228238938847268, ''),
#   Text(1.098393613943653, 0.059426162990736116, ''),
#   Text(1.0972899651747112, 0.07716691212483012, ''),
#   Text(1.0957933682144672, 0.09610876222901549, ''),
#   Text(1.0939698141454062, 0.11502193590209456, ''),
#   Text(1.0919683928487418, 0.13268394409021694, ''),
#   Text(1.0896818394542467, 0.15031130617358515, ''),
#   Text(1.0871107510211129, 0.16789941933881836, ''),
#   Text(1.0841522981242897, 0.1860478284523136, ''),
#   Text(1.0807769736857342, 0.20474650949578108, ''),
#   Text(1.0772034789518232, 0.22278389738508728, ''),
#   Text(1.0739955843195006, 0.23776771198422803, ''),
#   Text(1.0708602352436807, 0.2515121400128617, ''),
#   Text(1.0669552183327564, 0.2675940247324296, ''),
#   Text(1.0626505023711554, 0.28420751188230625, ''),
# ...

# %% [markdown]
# # Boxplot

# %%
snb.boxplot(data=d,orient='h')
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Heatmap

# %%
snb.heatmap(d.corr(),cmap='coolwarm',annot=True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Scatterplot

# %%
snb.jointplot(data=d,x='petal_length',y='sepal_length',kind='scatter')

# %% [markdown]
# # Barchart

# %%
d.plot.bar()
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Hexbin

# %%
d.plot.hexbin(x='petal_width',y='sepal_width',grid=5)
# Out:
# <AxesSubplot: xlabel='petal_width', ylabel='sepal_width'>
